# %%
# !numba -s
# Out:
# System info:
# --------------------------------------------------------------------------------
# __Time Stamp__
# Report started (local time)                   : 2021-02-25 21:01:28.510109
# UTC start time                                : 2021-02-26 03:01:28.510116
# Running time (s)                              : 3.376585
#
# __Hardware Information__
# Machine                                       : x86_64
# CPU Name                                      : skylake
# CPU Count                                     : 4
# Number of accessible CPUs                     : 4
# List of accessible CPUs cores                 : 0 1 2 3
# CFS Restrictions (CPUs worth of runtime)      : None
#
# CPU Features                                  : 64bit adx aes avx avx2 bmi bmi2
#                                                 clflushopt cmov cx16 cx8 f16c fma
#                                                 fsgsbase fxsr invpcid lzcnt mmx
# ...
